# %%
# Import dependencies
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

#cities
# Out:
# 735

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # print(requests.get(city_url).json())
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | lorengau
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | yar-sale
# Processing Record 7 of Set 1 | ostrovnoy
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | waingapu
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | sobolevo
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | kalmunai
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | emba
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | valandovo
# Processing Record 22 of Set 1 | taoudenni
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | mitu
# Processing Record 26 of Set 1 | portland
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | gairatganj
# Processing Record 32 of Set 1 | urumqi
# Processing Record 33 of Set 1 | hofn
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | dunedin
# Processing Record 38 of Set 1 | cockburn town
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | abha
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | waddan
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | muros
# Processing Record 47 of Set 1 | morant bay
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | derzhavinsk
# Processing Record 50 of Set 1 | medea
# Processing Record 1 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 2 | papagaios
# Processing Record 3 of Set 2 | ibipeba
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | cao bang
# Processing Record 8 of Set 2 | vryheid
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | tamala
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | mabaruma
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | mayo
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | carolina
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | sorland
# Processing Record 28 of Set 2 | sisimiut
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | guelengdeng
# City not found. Skipping...
# Processing Record 32 of Set 2 | ariquemes
# Processing Record 33 of Set 2 | westport
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | stony plain
# Processing Record 40 of Set 2 | mehamn
# Processing Record 41 of Set 2 | riverton
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | ixtapa
# Processing Record 45 of Set 2 | galle
# Processing Record 46 of Set 2 | hovd
# Processing Record 47 of Set 2 | canutama
# Processing Record 48 of Set 2 | tumaco
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | requena
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | meulaboh
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | kawalu
# Processing Record 10 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 3 | vestmannaeyjar
# Processing Record 12 of Set 3 | saint-pierre
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | kokopo
# Processing Record 15 of Set 3 | puerto ayacucho
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 18 of Set 3 | verkhnevilyuysk
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | brownwood
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | pyu
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | santa cruz
# Processing Record 25 of Set 3 | san cristobal
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | hundorp
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | poya
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | port-gentil
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | santa marta
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | roald
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | stratford-upon-avon
# Processing Record 39 of Set 3 | dalbandin
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | pag
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | dogondoutchi
# Processing Record 44 of Set 3 | gamba
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | cam ranh
# Processing Record 47 of Set 3 | linxia
# Processing Record 48 of Set 3 | ahipara
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | pratapgarh
# Processing Record 1 of Set 4 | melfi
# Processing Record 2 of Set 4 | calbuco
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | alenquer
# Processing Record 7 of Set 4 | khandyga
# Processing Record 8 of Set 4 | paciran
# Processing Record 9 of Set 4 | san quintin
# Processing Record 10 of Set 4 | zarichne
# Processing Record 11 of Set 4 | coihaique
# Processing Record 12 of Set 4 | tessalit
# Processing Record 13 of Set 4 | viedma
# Processing Record 14 of Set 4 | kilindoni
# Processing Record 15 of Set 4 | elko
# Processing Record 16 of Set 4 | kibara
# Processing Record 17 of Set 4 | luena
# Processing Record 18 of Set 4 | flinders
# Processing Record 19 of Set 4 | masindi
# Processing Record 20 of Set 4 | berezovyy
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | port augusta
# Processing Record 23 of Set 4 | quang ngai
# Processing Record 24 of Set 4 | baykit
# Processing Record 25 of Set 4 | blyth
# Processing Record 26 of Set 4 | kudat
# Processing Record 27 of Set 4 | koroni
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | iquique
# Processing Record 30 of Set 4 | esil
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | west wendover
# Processing Record 33 of Set 4 | praia da vitoria
# Processing Record 34 of Set 4 | vostok
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | xichang
# Processing Record 37 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 4 | bubaque
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | xinxiang
# Processing Record 41 of Set 4 | paamiut
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | dehui
# Processing Record 45 of Set 4 | banff
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | dolores
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 5 | alofi
# Processing Record 3 of Set 5 | wilkes-barre
# Processing Record 4 of Set 5 | nehe
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | zonguldak
# Processing Record 8 of Set 5 | brownsville
# Processing Record 9 of Set 5 | gerstetten
# Processing Record 10 of Set 5 | honiara
# Processing Record 11 of Set 5 | frunze
# Processing Record 12 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 13 of Set 5 | varadero
# Processing Record 14 of Set 5 | safaga
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | coahuayana
# Processing Record 17 of Set 5 | pumiao
# Processing Record 18 of Set 5 | naze
# Processing Record 19 of Set 5 | cairns
# Processing Record 20 of Set 5 | kuandian
# Processing Record 21 of Set 5 | akyab
# Processing Record 22 of Set 5 | te anau
# Processing Record 23 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | biltine
# Processing Record 26 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 27 of Set 5 | itoman
# Processing Record 28 of Set 5 | aksu
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | ye
# City not found. Skipping...
# Processing Record 31 of Set 5 | ndende
# Processing Record 32 of Set 5 | pervomaysk
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | soria
# Processing Record 35 of Set 5 | butembo
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | bastia
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | pa sang
# Processing Record 40 of Set 5 | rawson
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | celestun
# Processing Record 43 of Set 5 | nantucket
# Processing Record 44 of Set 5 | trincomalee
# Processing Record 45 of Set 5 | road town
# Processing Record 46 of Set 5 | hit
# Processing Record 47 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 5 | alyangula
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5 | jaguaruna
# Processing Record 1 of Set 6 | half moon bay
# Processing Record 2 of Set 6 | matara
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | vincennes
# Processing Record 6 of Set 6 | boma
# Processing Record 7 of Set 6 | armidale
# Processing Record 8 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | qasigiannguit
# Processing Record 12 of Set 6 | mudu
# Processing Record 13 of Set 6 | kamenka
# Processing Record 14 of Set 6 | pokhara
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | san carlos park
# Processing Record 17 of Set 6 | arlit
# Processing Record 18 of Set 6 | chateaubelair
# Processing Record 19 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 6 | pacific grove
# Processing Record 21 of Set 6 | torbay
# Processing Record 22 of Set 6 | praia
# Processing Record 23 of Set 6 | san matias
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | mar del plata
# Processing Record 27 of Set 6 | beyneu
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | salym
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | saint anthony
# Processing Record 32 of Set 6 | bredasdorp
# Processing Record 33 of Set 6 | aswan
# Processing Record 34 of Set 6 | caravelas
# Processing Record 35 of Set 6 | laurel
# Processing Record 36 of Set 6 | dikson
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | sola
# Processing Record 39 of Set 6 | rochefort
# Processing Record 40 of Set 6 | nuuk
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | cherskiy
# Processing Record 43 of Set 6 | dali
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | atambua
# Processing Record 46 of Set 6 | miraflores
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | hashtrud
# Processing Record 49 of Set 6 | balykshi
# Processing Record 50 of Set 6 | amapa
# Processing Record 1 of Set 7 | ravensburg
# Processing Record 2 of Set 7 | mendi
# Processing Record 3 of Set 7 | byron bay
# Processing Record 4 of Set 7 | isangel
# Processing Record 5 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 7 | erzin
# Processing Record 7 of Set 7 | zeya
# Processing Record 8 of Set 7 | jalu
# Processing Record 9 of Set 7 | san jeronimo
# Processing Record 10 of Set 7 | pimenta bueno
# Processing Record 11 of Set 7 | batemans bay
# Processing Record 12 of Set 7 | sungaipenuh
# Processing Record 13 of Set 7 | college place
# Processing Record 14 of Set 7 | saiha
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | la rioja
# Processing Record 18 of Set 7 | lubao
# Processing Record 19 of Set 7 | babstovo
# Processing Record 20 of Set 7 | nyeri
# Processing Record 21 of Set 7 | comodoro rivadavia
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | dublin
# Processing Record 24 of Set 7 | the valley
# Processing Record 25 of Set 7 | lazaro cardenas
# Processing Record 26 of Set 7 | gladstone
# Processing Record 27 of Set 7 | gilgit
# Processing Record 28 of Set 7 | oyek
# Processing Record 29 of Set 7 | garden city
# Processing Record 30 of Set 7 | carbonia
# Processing Record 31 of Set 7 | trenggalek
# Processing Record 32 of Set 7 | show low
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | mareeba
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | leningradskiy
# Processing Record 37 of Set 7 | ossora
# Processing Record 38 of Set 7 | oussouye
# Processing Record 39 of Set 7 | mutum
# Processing Record 40 of Set 7 | bontang
# Processing Record 41 of Set 7 | lens
# Processing Record 42 of Set 7 | montepuez
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | paiania
# Processing Record 45 of Set 7 | sarkand
# Processing Record 46 of Set 7 | bulgan
# Processing Record 47 of Set 7 | yulara
# Processing Record 48 of Set 7 | zhangjiakou
# Processing Record 49 of Set 7 | tianpeng
# Processing Record 50 of Set 7 | nurota
# Processing Record 1 of Set 8 | wabag
# Processing Record 2 of Set 8 | karacabey
# Processing Record 3 of Set 8 | turbat
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | harper
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | vung tau
# Processing Record 9 of Set 8 | rio gallegos
# Processing Record 10 of Set 8 | cap malheureux
# Processing Record 11 of Set 8 | luganville
# Processing Record 12 of Set 8 | tekkali
# Processing Record 13 of Set 8 | fairbanks
# Processing Record 14 of Set 8 | paraiso
# Processing Record 15 of Set 8 | oktyabrskiy
# Processing Record 16 of Set 8 | det udom
# Processing Record 17 of Set 8 | sangar
# Processing Record 18 of Set 8 | altamira
# Processing Record 19 of Set 8 | ust-barguzin
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | champerico
# Processing Record 22 of Set 8 | dubbo
# Processing Record 23 of Set 8 | lomitas
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | milkovo
# Processing Record 27 of Set 8 | kingaroy
# Processing Record 28 of Set 8 | imeni poliny osipenko
# Processing Record 29 of Set 8 | voitsberg
# Processing Record 30 of Set 8 | georgetown
# Processing Record 31 of Set 8 | tacna
# Processing Record 32 of Set 8 | mansfield
# Processing Record 33 of Set 8 | bongandanga
# Processing Record 34 of Set 8 | kirtipur
# Processing Record 35 of Set 8 | waipawa
# Processing Record 36 of Set 8 | hervey bay
# Processing Record 37 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 8 | boden
# Processing Record 39 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | agadez
# Processing Record 41 of Set 8 | monopoli
# Processing Record 42 of Set 8 | camopi
# Processing Record 43 of Set 8 | huarmey
# Processing Record 44 of Set 8 | dudinka
# Processing Record 45 of Set 8 | pozo colorado
# Processing Record 46 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 8 | bayan
# Processing Record 48 of Set 8 | babu
# Processing Record 49 of Set 8 | nanortalik
# Processing Record 50 of Set 8 | puerto escondido
# Processing Record 1 of Set 9 | mattru
# Processing Record 2 of Set 9 | nome
# Processing Record 3 of Set 9 | outjo
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | izumo
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | meadow lake
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | pingliang
# Processing Record 10 of Set 9 | hamilton
# Processing Record 11 of Set 9 | santa isabel do rio negro
# Processing Record 12 of Set 9 | shelburne
# Processing Record 13 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 14 of Set 9 | lar
# Processing Record 15 of Set 9 | lavrentiya
# Processing Record 16 of Set 9 | boyolangu
# Processing Record 17 of Set 9 | tigil
# Processing Record 18 of Set 9 | sechura
# Processing Record 19 of Set 9 | napanee
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | la asuncion
# Processing Record 22 of Set 9 | berlevag
# Processing Record 23 of Set 9 | leh
# Processing Record 24 of Set 9 | ardakan
# Processing Record 25 of Set 9 | bouar
# Processing Record 26 of Set 9 | kirakira
# Processing Record 27 of Set 9 | dhidhdhoo
# Processing Record 28 of Set 9 | totness
# Processing Record 29 of Set 9 | jiwani
# Processing Record 30 of Set 9 | zenzeli
# Processing Record 31 of Set 9 | manokwari
# Processing Record 32 of Set 9 | saint george
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | ternate
# Processing Record 35 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 9 | jardim
# Processing Record 37 of Set 9 | mae ramat
# Processing Record 38 of Set 9 | nishihara
# Processing Record 39 of Set 9 | marawi
# Processing Record 40 of Set 9 | shemysheyka
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | eureka
# Processing Record 43 of Set 9 | narsaq
# Processing Record 44 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 45 of Set 9 | margate
# Processing Record 46 of Set 9 | tibati
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | gwalior
# Processing Record 49 of Set 9 | nago
# Processing Record 50 of Set 9 | nagato
# Processing Record 1 of Set 10 | kroya
# Processing Record 2 of Set 10 | carballo
# Processing Record 3 of Set 10 | tual
# Processing Record 4 of Set 10 | khasan
# Processing Record 5 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 10 | adrar
# Processing Record 7 of Set 10 | rocha
# Processing Record 8 of Set 10 | sakakah
# Processing Record 9 of Set 10 | chicama
# Processing Record 10 of Set 10 | bendigo
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | padang
# Processing Record 13 of Set 10 | maarianhamina
# Processing Record 14 of Set 10 | ahuimanu
# Processing Record 15 of Set 10 | plotnikovo
# Processing Record 16 of Set 10 | along
# Processing Record 17 of Set 10 | waitara
# Processing Record 18 of Set 10 | anloga
# Processing Record 19 of Set 10 | kongolo
# Processing Record 20 of Set 10 | collie
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | luanda
# Processing Record 23 of Set 10 | lac du bonnet
# Processing Record 24 of Set 10 | teguise
# Processing Record 25 of Set 10 | coruripe
# Processing Record 26 of Set 10 | kozhva
# Processing Record 27 of Set 10 | ajaccio
# Processing Record 28 of Set 10 | gumdag
# Processing Record 29 of Set 10 | san juan
# Processing Record 30 of Set 10 | margara
# Processing Record 31 of Set 10 | maragogi
# Processing Record 32 of Set 10 | rio bueno
# Processing Record 33 of Set 10 | suez
# Processing Record 34 of Set 10 | glendive
# Processing Record 35 of Set 10 | san pedro
# Processing Record 36 of Set 10 | iskateley
# Processing Record 37 of Set 10 | kahului
# Processing Record 38 of Set 10 | pekalongan
# Processing Record 39 of Set 10 | carauari
# Processing Record 40 of Set 10 | jhanjharpur
# Processing Record 41 of Set 10 | sabang
# Processing Record 42 of Set 10 | pahrump
# Processing Record 43 of Set 10 | zaraza
# Processing Record 44 of Set 10 | padilla
# Processing Record 45 of Set 10 | shenjiamen
# Processing Record 46 of Set 10 | bloomfield
# Processing Record 47 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 10 | shostka
# Processing Record 49 of Set 10 | ewo
# Processing Record 50 of Set 10 | pevek
# Processing Record 1 of Set 11 | mufumbwe
# Processing Record 2 of Set 11 | deer lake
# Processing Record 3 of Set 11 | kendari
# Processing Record 4 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 5 of Set 11 | watsa
# Processing Record 6 of Set 11 | kupang
# Processing Record 7 of Set 11 | pontianak
# Processing Record 8 of Set 11 | santa cruz de tenerife
# Processing Record 9 of Set 11 | mizdah
# Processing Record 10 of Set 11 | san ignacio
# Processing Record 11 of Set 11 | turukhansk
# Processing Record 12 of Set 11 | les escoumins
# Processing Record 13 of Set 11 | caronport
# Processing Record 14 of Set 11 | grand gaube
# Processing Record 15 of Set 11 | santa rosa
# Processing Record 16 of Set 11 | quatre cocos
# Processing Record 17 of Set 11 | twin falls
# Processing Record 18 of Set 11 | ciudad bolivar
# Processing Record 19 of Set 11 | alekseyevsk
# Processing Record 20 of Set 11 | luoyang
# Processing Record 21 of Set 11 | halmstad
# Processing Record 22 of Set 11 | nadym
# Processing Record 23 of Set 11 | plunge
# Processing Record 24 of Set 11 | karratha
# Processing Record 25 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 11 | kukmor
# Processing Record 27 of Set 11 | flagstaff
# Processing Record 28 of Set 11 | marzuq
# Processing Record 29 of Set 11 | zomin
# Processing Record 30 of Set 11 | ocos
# Processing Record 31 of Set 11 | jamame
# Processing Record 32 of Set 11 | altay
# Processing Record 33 of Set 11 | nesbyen
# Processing Record 34 of Set 11 | juanjui
# Processing Record 35 of Set 11 | neuquen
# Processing Record 36 of Set 11 | namibe
# Processing Record 37 of Set 11 | whitianga
# Processing Record 38 of Set 11 | qiongshan
# Processing Record 39 of Set 11 | nobeoka
# Processing Record 40 of Set 11 | shangzhi
# Processing Record 41 of Set 11 | filadelfia
# Processing Record 42 of Set 11 | ingham
# Processing Record 43 of Set 11 | minatitlan
# Processing Record 44 of Set 11 | yichun
# Processing Record 45 of Set 11 | mocuba
# Processing Record 46 of Set 11 | deniliquin
# Processing Record 47 of Set 11 | kavaratti
# Processing Record 48 of Set 11 | bad neuenahr-ahrweiler
# Processing Record 49 of Set 11 | naspur
# Processing Record 50 of Set 11 | cozumel
# Processing Record 1 of Set 12 | sept-iles
# Processing Record 2 of Set 12 | bahua
# Processing Record 3 of Set 12 | kampong thum
# Processing Record 4 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 12 | rach gia
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | ibra
# Processing Record 8 of Set 12 | jega
# Processing Record 9 of Set 12 | kununurra
# Processing Record 10 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 12 | sarangani
# Processing Record 12 of Set 12 | salinopolis
# Processing Record 13 of Set 12 | sistranda
# Processing Record 14 of Set 12 | maiduguri
# Processing Record 15 of Set 12 | srivardhan
# Processing Record 16 of Set 12 | havoysund
# Processing Record 17 of Set 12 | sydney
# Processing Record 18 of Set 12 | ponta do sol
# Processing Record 19 of Set 12 | mahibadhoo
# Processing Record 20 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 12 | dulce grande
# Processing Record 22 of Set 12 | avera
# Processing Record 23 of Set 12 | colares
# Processing Record 24 of Set 12 | flin flon
# Processing Record 25 of Set 12 | belle fourche
# Processing Record 26 of Set 12 | zhaodong
# Processing Record 27 of Set 12 | amga
# Processing Record 28 of Set 12 | santa maria
# Processing Record 29 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 12 | greystones
# Processing Record 31 of Set 12 | hualmay
# Processing Record 32 of Set 12 | san carlos de bariloche
# Processing Record 33 of Set 12 | ayan
# Processing Record 34 of Set 12 | kyaikkami
# Processing Record 35 of Set 12 | beocin
# Processing Record 36 of Set 12 | dillon
# Processing Record 37 of Set 12 | port hueneme
# Processing Record 38 of Set 12 | filingue
# Processing Record 39 of Set 12 | cururupu
# Processing Record 40 of Set 12 | atka
# City not found. Skipping...
# Processing Record 41 of Set 12 | buchanan
# Processing Record 42 of Set 12 | kapoeta
# Processing Record 43 of Set 12 | oviedo
# Processing Record 44 of Set 12 | ampanihy
# Processing Record 45 of Set 12 | port keats
# Processing Record 46 of Set 12 | fulitun
# City not found. Skipping...
# Processing Record 47 of Set 12 | osorno
# Processing Record 48 of Set 12 | mauganj
# Processing Record 49 of Set 12 | campoverde
# Processing Record 50 of Set 12 | nhulunbuy
# Processing Record 1 of Set 13 | jerantut
# Processing Record 2 of Set 13 | bairiki
# Processing Record 3 of Set 13 | progreso
# Processing Record 4 of Set 13 | kushmurun
# Processing Record 5 of Set 13 | los llanos de aridane
# Processing Record 6 of Set 13 | sao filipe
# Processing Record 7 of Set 13 | miyako
# Processing Record 8 of Set 13 | naliya
# Processing Record 9 of Set 13 | neiafu
# Processing Record 10 of Set 13 | riohacha
# Processing Record 11 of Set 13 | saint-augustin
# Processing Record 12 of Set 13 | swan hill
# Processing Record 13 of Set 13 | santiago de cao
# Processing Record 14 of Set 13 | lusambo
# Processing Record 15 of Set 13 | vermillion
# Processing Record 16 of Set 13 | morros
# Processing Record 17 of Set 13 | talara
# Processing Record 18 of Set 13 | college
# Processing Record 19 of Set 13 | wamba
# Processing Record 20 of Set 13 | bealanana
# Processing Record 21 of Set 13 | porto walter
# Processing Record 22 of Set 13 | puerto penasco
# Processing Record 23 of Set 13 | oktyabrskoye
# Processing Record 24 of Set 13 | glendora
# Processing Record 25 of Set 13 | beloha
# Processing Record 26 of Set 13 | katha
# City not found. Skipping...
# Processing Record 27 of Set 13 | malanje
# Processing Record 28 of Set 13 | naro
# Processing Record 29 of Set 13 | kortkeros
# Processing Record 30 of Set 13 | northam
# Processing Record 31 of Set 13 | clarence town
# Processing Record 32 of Set 13 | mchinji
# Processing Record 33 of Set 13 | algeciras
# Processing Record 34 of Set 13 | yining
# Processing Record 35 of Set 13 | suamico
# Processing Record 36 of Set 13 | toamasina
# Processing Record 37 of Set 13 | storforshei
# Processing Record 38 of Set 13 | novyy urengoy
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | ponta delgada
# Processing Record 41 of Set 13 | lebedinyy
# Processing Record 42 of Set 13 | bilma
# Processing Record 43 of Set 13 | rosetta
# Processing Record 44 of Set 13 | yarensk
# Processing Record 45 of Set 13 | batagay-alyta
# Processing Record 46 of Set 13 | yangcun
# Processing Record 47 of Set 13 | abu samrah
# Processing Record 48 of Set 13 | chapais
# Processing Record 49 of Set 13 | vanimo
# Processing Record 50 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 14 | henties bay
# Processing Record 2 of Set 14 | mormugao
# Processing Record 3 of Set 14 | winsum
# Processing Record 4 of Set 14 | gunnedah
# Processing Record 5 of Set 14 | lethem
# Processing Record 6 of Set 14 | pointe michel
# Processing Record 7 of Set 14 | kirando
# Processing Record 8 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 14 | sirjan
# Processing Record 10 of Set 14 | kloulklubed
# Processing Record 11 of Set 14 | caluquembe
# Processing Record 12 of Set 14 | balakhninskiy
# Processing Record 13 of Set 14 | wuhu
# Processing Record 14 of Set 14 | freeport
# Processing Record 15 of Set 14 | zhigansk
# Processing Record 16 of Set 14 | shihezi
# Processing Record 17 of Set 14 | bela
# Processing Record 18 of Set 14 | svodna
# Processing Record 19 of Set 14 | guilin
# Processing Record 20 of Set 14 | qingdao
# Processing Record 21 of Set 14 | le port
# Processing Record 22 of Set 14 | bonfim
# Processing Record 23 of Set 14 | madang
# Processing Record 24 of Set 14 | maniitsoq
# Processing Record 25 of Set 14 | beibei
# Processing Record 26 of Set 14 | keta
# Processing Record 27 of Set 14 | ishikari
# Processing Record 28 of Set 14 | pereslavl-zalesskiy
# Processing Record 29 of Set 14 | dhenkanal
# Processing Record 30 of Set 14 | ust-kan
# Processing Record 31 of Set 14 | lucea
# Processing Record 32 of Set 14 | skjervoy
# Processing Record 33 of Set 14 | kuytun
# Processing Record 34 of Set 14 | koslan
# Processing Record 35 of Set 14 | antofagasta
# Processing Record 36 of Set 14 | sault sainte marie
# Processing Record 37 of Set 14 | sao jose da coroa grande
# Processing Record 38 of Set 14 | lebedyn
# Processing Record 39 of Set 14 | ilula
# Processing Record 40 of Set 14 | rey bouba
# Processing Record 41 of Set 14 | nha trang
# Processing Record 42 of Set 14 | snezhnogorsk
# Processing Record 43 of Set 14 | madimba
# Processing Record 44 of Set 14 | valparaiso
# Processing Record 45 of Set 14 | russkaya polyana
# Processing Record 46 of Set 14 | mega
# Processing Record 47 of Set 14 | barcelos
# Processing Record 48 of Set 14 | manthani
# Processing Record 49 of Set 14 | canton
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | lincoln
# Processing Record 2 of Set 15 | yenisea
# City not found. Skipping...
# Processing Record 3 of Set 15 | novo aripuana
# Processing Record 4 of Set 15 | kadugannawa
# Processing Record 5 of Set 15 | pedasi
# Processing Record 6 of Set 15 | novocheremshansk
# Processing Record 7 of Set 15 | mumford
# Processing Record 8 of Set 15 | sao gabriel da cachoeira
# Processing Record 9 of Set 15 | noumea
# Processing Record 10 of Set 15 | kapit
# Processing Record 11 of Set 15 | pemangkat
# Processing Record 12 of Set 15 | mahina
# Processing Record 13 of Set 15 | kaita
# Processing Record 14 of Set 15 | sosnovo-ozerskoye
# Processing Record 15 of Set 15 | bafq
# Processing Record 16 of Set 15 | yumen
# Processing Record 17 of Set 15 | maketu
# Processing Record 18 of Set 15 | awjilah
# Processing Record 19 of Set 15 | ndele
# Processing Record 20 of Set 15 | chumikan
# Processing Record 21 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 15 | pemba
# Processing Record 23 of Set 15 | tacuarembo
# Processing Record 24 of Set 15 | high level
# Processing Record 25 of Set 15 | whitecourt
# Processing Record 26 of Set 15 | rapid valley
# Processing Record 27 of Set 15 | madison heights
# Processing Record 28 of Set 15 | miedzyrzecz
# Processing Record 29 of Set 15 | saint-denis
# Processing Record 30 of Set 15 | snasa
# Processing Record 31 of Set 15 | moron
# Processing Record 32 of Set 15 | igrim
# Processing Record 33 of Set 15 | ahmadpur
# Processing Record 34 of Set 15 | ilhabela
# Processing Record 35 of Set 15 | fuxin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Atuona  -9.8000 -139.0333     77.07        72           3
# 1       Lorengau  -2.0226  147.2712     81.57        79         100
# 2  Mount Gambier -37.8333  140.7667     50.70        89          40
# 3   Puerto Ayora  -0.7393  -90.3518     68.56        98         100
# 4       Yar-Sale  66.8333   70.8333     50.29        81          99
# 5      Ostrovnoy  68.0531   39.5131     65.39        60         100
# 6     Nikolskoye  59.7035   30.7861     85.87        36          24
# 7        Salalah  17.0151   54.0924     76.42        96         100
# 8       Waingapu  -9.6567  120.2641     73.49        81          17
# 9          Tiksi  71.6872  128.8694     50.74        88          45
#
#    Wind Speed Country                 Date
# 0       16.20      PF  2022-07-26 13:50:16
# 1        9.62      PG  2022-07-26 13:50:17
# 2        9.06      AU  2022-07-26 13:50:17
# 3        5.99      EC  2022-07-26 13:50:17
# 4       17.60      RU  2022-07-26 13:50:18
# 5       21.09      RU  2022-07-26 13:50:18
# 6        8.21      RU  2022-07-26 13:50:19
# 7        7.94      OM  2022-07-26 13:50:19
# 8        9.22      ID  2022-07-26 13:50:19
# 9        2.44      RU  2022-07-26 13:50:20

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0           Atuona      PF  2022-07-26 13:50:16  -9.8000 -139.0333     77.07
# 1         Lorengau      PG  2022-07-26 13:50:17  -2.0226  147.2712     81.57
# 2    Mount Gambier      AU  2022-07-26 13:50:17 -37.8333  140.7667     50.70
# 3     Puerto Ayora      EC  2022-07-26 13:50:17  -0.7393  -90.3518     68.56
# 4         Yar-Sale      RU  2022-07-26 13:50:18  66.8333   70.8333     50.29
# ..             ...     ...                  ...      ...       ...       ...
# 678          Moron      AR  2022-07-26 14:08:33 -34.6534  -58.6198     67.01
# 679          Igrim      RU  2022-07-26 14:08:33  63.1906   64.4162     65.14
# 680       Ahmadpur      IN  2022-07-26 14:08:34  18.7000   76.9333     75.69
# 681       Ilhabela      BR  2022-07-26 14:08:34 -23.7781  -45.3581     72.97
# 682          Fuxin      CN  2022-07-26 14:08:35  42.0156  121.6589     71.71
#
#      Humidity  Cloudiness  Wind Speed
# 0          72           3       16.20
# 1          79         100        9.62
# 2          89          40        9.06
# 3          98         100        5.99
# 4          81          99       17.60
# ..        ...         ...         ...
# 678        93         100        4.61
# 679        42          66        7.87
# 680        86         100        3.22
# 681        72           2        3.24
# 682        81           1        4.92
#
# [683 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
